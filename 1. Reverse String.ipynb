# %%
input_string = "this"

revesed_str = ""
for char in input_string:
   
    revesed_str = char + revesed_str
print(revesed_str)
# Out:
# siht

# %%
def reverse_string(input_string: str) -> str:
    """
    Funtion to reverse a given string using for loop.
    Args:
        input_str(str):The string to be reversed.
    Returns:
        str: The revesed version of input string.
    Raises:
        TypeError: If input is not a string.
    """
    # validate the input type
    if not isinstance(input_string,str):
        raise TypeError("Input must be a string")
    revesed_str = ""
    for char in input_string:
        revesed_str = char + revesed_str
    return revesed_str   
# ----Main Execuation ----    
if __name__ == "__main__":
    try:
        # Taking input from the user
        user_input = input("Enter your string to reverse : ")
        # calling the function
        result = reverse_string(user_input)
        # Display the reversed string
        print(f"Reversed string :{result}")    
    except TypeError as e:
        print(e)
    except Exception as e:
        print(e)
# Out:
# Enter your string to reverse :  (1,2,,3,,4
# Reversed string :4,,3,,2,1(

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print("dkj",djfkdjf)
#
# NameError: name 'djfkdjf' is not defined

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'input_string = "Python"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#   'input_string = "hi"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#   'print("dkj",djfkdjf)',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        ',
#   'globals()',
#   'type(globals())',
#   'globals()'],
#  '_oh': {7: {...}, 8: dict},
#  '_dh': [WindowsPath('E:/Python 50 Questions Answer')],
#  'In': ['',
#   'input_string = "Python"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#   'input_string = "hi"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#   'print("dkj",djfkdjf)',
#   'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        ',
#   'globals()',
#   'type(globals())',
#   'globals()'],
#  'Out': {7: {...}, 8: dict},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001800CD89290>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1800cd95b90>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1800cd95b90>,
#  'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': dict,
#  '__': {...},
#  '___': '',
#  '__session__': 'E:\\Python 50 Questions Answer\\1. Reverse String.ipynb',
#  '_i': 'type(globals())',
#  '_ii': 'globals()',
#  '_iii': 'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        ',
#  '_i1': 'input_string = "Python"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#  'input_string': 'hi',
#  'revesed_str': 'ih',
#  'char': 'i',
#  '_i2': 'input_string = "hi"\n\nrevesed_str = ""\nfor char in input_string:\n   \n    revesed_str = char + revesed_str\nprint(revesed_str)\n   ',
#  '_i3': 'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#  'reverse_string': <function __main__.reverse_string(input_string: str) -> str>,
#  'user_input': 'gkfdgjldksfgjfdklg',
#  'result': 'glkdfjgfskdljgdfkg',
#  '_i4': 'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        \n    \n    ',
#  '_i5': 'print("dkj",djfkdjf)',
#  '_i6': 'def reverse_string(input_string: str) -> str:\n    """\n    Funtion to reverse a given string using for loop.\n    Args:\n        input_str(str):The string to be reversed.\n    Returns:\n        str: The revesed version of input string.\n    Raises:\n        TypeError: If input is not a string.\n    """\n    # validate the input type\n    if not isinstance(input_string,str):\n        raise TypeError("Input must be a string")\n    revesed_str = ""\n    for char in input_string:\n        revesed_str = char + revesed_str\n    return revesed_str   \n# ----Main Execuation ----    \nif __name__ == "__main__":\n    try:\n        # Taking input from the user\n        user_input = input("Enter your string to reverse : ")\n        # calling the function\n        result = reverse_string(user_input)\n        # Display the reversed string\n        print(f"Reversed string :{result}")    \n    except TypeError as e:\n        print(e)\n    except Exception as e:\n        print(e)\n        ',
#  '_i7': 'globals()',
#  '_7': {...},
#  '_i8': 'type(globals())',
#  '_8': dict,
#  '_i9': 'globals()'}
